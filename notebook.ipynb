# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# # 1. Import Dataset

# %%
student_df = pd.read_csv('data/StudentPerformanceFactors.csv')
student_data = pd.concat([student_df])
student_data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
student_data.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
student_data.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
print("Male Average Score:", student_data[student_data['Gender']=='Male']['Exam_Score'].mean())
print("Female Average Score:", student_data[student_data['Gender']=='Female']['Exam_Score'].mean())
# Out:
# Male Average Score: 67.22889355007865
# Female Average Score: 67.24489795918367

# %%
student_data.shape
# Out:
# (6607, 20)

# %% [markdown]
# # 2. Data Exploration

# %%
student_data.hist(figsize=(30,15), bins=30)
# Out:
# array([[<Axes: title={'center': 'Hours_Studied'}>,
#         <Axes: title={'center': 'Attendance'}>,
#         <Axes: title={'center': 'Sleep_Hours'}>],
#        [<Axes: title={'center': 'Previous_Scores'}>,
#         <Axes: title={'center': 'Tutoring_Sessions'}>,
#         <Axes: title={'center': 'Physical_Activity'}>],
#        [<Axes: title={'center': 'Exam_Score'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
print(student_data['Parental_Involvement'].value_counts())
print(student_data['Access_to_Resources'].value_counts())
print(student_data['Extracurricular_Activities'].value_counts())
print(student_data['Motivation_Level'].value_counts())
print(student_data['Internet_Access'].value_counts())
print(student_data['Family_Income'].value_counts())
print(student_data['Teacher_Quality'].value_counts())
print(student_data['School_Type'].value_counts())
print(student_data['Peer_Influence'].value_counts())
print(student_data['Learning_Disabilities'].value_counts())
print(student_data['Parental_Education_Level'].value_counts())
print(student_data['Distance_from_Home'].value_counts())
print(student_data['Gender'].value_counts())
# Out:
# Parental_Involvement
# Medium    3362
# High      1908
# Low       1337
# Name: count, dtype: int64
# Access_to_Resources
# Medium    3319
# High      1975
# Low       1313
# Name: count, dtype: int64
# Extracurricular_Activities
# Yes    3938
# No     2669
# Name: count, dtype: int64
# Motivation_Level
# Medium    3351
# Low       1937
# High      1319
# Name: count, dtype: int64
# Internet_Access
# Yes    6108
# No      499
# Name: count, dtype: int64
# Family_Income
# Low       2672
# Medium    2666
# High      1269
# Name: count, dtype: int64
# Teacher_Quality
# Medium    3925
# High      1947
# Low        657
# Name: count, dtype: int64
# School_Type
# Public     4598
# Private    2009
# Name: count, dtype: int64
# Peer_Influence
# Positive    2638
# Neutral     2592
# Negative    1377
# Name: count, dtype: int64
# Learning_Disabilities
# No     5912
# Yes     695
# Name: count, dtype: int64
# Parental_Education_Level
# High School     3223
# College         1989
# ...

# %% [markdown]
# # 3. Data Cleaning

# %%
student_data.isna().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
student_data['Teacher_Quality'].value_counts()
# Out:
# Teacher_Quality
# Medium    3925
# High      1947
# Low        657
# Name: count, dtype: int64

# %%
categorical_features = ['Parental_Involvement', 'Motivation_Level', 'School_Type']
input_features = categorical_features + ['Hours_Studied', 'Attendance', 'Previous_Scores', 'Tutoring_Sessions']
target_feature = 'Teacher_Quality'

# %%
teacher_model_data = student_data.copy()

# %%
teacher_model_data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

train_data = teacher_model_data.dropna(subset=['Teacher_Quality'])
test_data = teacher_model_data[teacher_model_data['Teacher_Quality'].isna()]

# Preparing predictors and target
X_train = train_data[input_features]
y_train = train_data[target_feature]
X_test = test_data[input_features]

X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# Create and fit the model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict the missing values
predicted_values = model.predict(X_test)

# Fill in the missing values in the original DataFrame
teacher_model_data.loc[teacher_model_data['Teacher_Quality'].isna(), 'Teacher_Quality'] = predicted_values

# %%
teacher_model_data['Teacher_Quality'].value_counts()
# Out:
# Teacher_Quality
# Medium    3984
# High      1966
# Low        657
# Name: count, dtype: int64

# %%
teacher_model_data['Parental_Education_Level'].value_counts()
# Out:
# Parental_Education_Level
# High School     3223
# College         1989
# Postgraduate    1305
# Name: count, dtype: int64

# %%
categorical_features = ['Parental_Involvement', 'Access_to_Resources', 'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access', 'Family_Income', 'School_Type', 'Peer_Influence']
input_features = categorical_features + ['Hours_Studied', 'Attendance', 'Sleep_Hours']
target_feature = 'Parental_Education_Level'

# %%
parent_education_model_data = teacher_model_data.copy()

# %%
parent_education_model_data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

train_data = parent_education_model_data.dropna(subset=['Parental_Education_Level'])
test_data = parent_education_model_data[parent_education_model_data['Parental_Education_Level'].isna()]

# Preparing predictors and target
X_train = train_data[input_features]
y_train = train_data[target_feature]
X_test = test_data[input_features]

X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# Create and fit the model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict the missing values
predicted_values = model.predict(X_test)

# Fill in the missing values in the original DataFrame
parent_education_model_data.loc[parent_education_model_data['Parental_Education_Level'].isna(), 'Parental_Education_Level'] = predicted_values

# %%
parent_education_model_data['Parental_Education_Level'].value_counts()
# Out:
# Parental_Education_Level
# High School     3284
# College         2014
# Postgraduate    1309
# Name: count, dtype: int64

# %%
parent_education_model_data['Distance_from_Home'].value_counts()
# Out:
# Distance_from_Home
# Near        3884
# Moderate    1998
# Far          658
# Name: count, dtype: int64

# %%
categorical_features = ['Access_to_Resources', 'Extracurricular_Activities', 'Tutoring_Sessions', 'School_Type']
input_features = categorical_features + ['Attendance']
target_feature = 'Distance_from_Home'

# %%
distance_model_data = parent_education_model_data.copy()

# %%
distance_model_data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

train_data = distance_model_data.dropna(subset=['Distance_from_Home'])
test_data = distance_model_data[distance_model_data['Distance_from_Home'].isna()]

# Preparing predictors and target
X_train = train_data[input_features]
y_train = train_data[target_feature]
X_test = test_data[input_features]

X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# Create and fit the model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict the missing values
predicted_values = model.predict(X_test)

# Fill in the missing values in the original DataFrame
distance_model_data.loc[distance_model_data['Distance_from_Home'].isna(), 'Distance_from_Home'] = predicted_values

# %%
distance_model_data['Distance_from_Home'].value_counts()
# Out:
# Distance_from_Home
# Near        3929
# Moderate    2016
# Far          662
# Name: count, dtype: int64

# %%
distance_model_data.isna().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %% [markdown]
# # 4. Data Preparation

# %%
student_data_prepared = distance_model_data.copy()

# %%
student_data_prepared.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
student_data_prepared.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
student_data_prepared.hist(figsize = (30,15), bins = 30)
# Out:
# array([[<Axes: title={'center': 'Hours_Studied'}>,
#         <Axes: title={'center': 'Attendance'}>,
#         <Axes: title={'center': 'Sleep_Hours'}>],
#        [<Axes: title={'center': 'Previous_Scores'}>,
#         <Axes: title={'center': 'Tutoring_Sessions'}>,
#         <Axes: title={'center': 'Physical_Activity'}>],
#        [<Axes: title={'center': 'Exam_Score'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
print(student_data_prepared.shape)
student_data_prepared[student_data_prepared['Hours_Studied']>=38].shape
# Out:
# (6607, 20)
# (16, 20)

# %%
student_data_prepared[student_data_prepared['Exam_Score']>90].shape
# Out:
# (22, 20)

# %%
student_data_prepared[student_data_prepared['Tutoring_Sessions']>5].shape
# Out:
# (26, 20)

# %%
student_data_prepared = student_data_prepared[student_data_prepared['Exam_Score']<=90]
student_data_prepared = student_data_prepared[student_data_prepared['Hours_Studied']<38]
student_data_prepared = student_data_prepared[student_data_prepared['Tutoring_Sessions']<=5]

# %%
print(student_data_prepared.shape)
student_data_prepared
# Out:
# (6543, 20)
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
categorical_columns = ['Parental_Involvement', 'Access_to_Resources', 'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions', 'Teacher_Quality', 'Learning_Disabilities']
numerical_columns = ['Hours_Studied', 'Attendance', 'Exam_Score']
all_needed_columns = categorical_columns + numerical_columns

# %%
main_student_df = student_data_prepared[all_needed_columns]
print(main_student_df.shape)
main_student_df.head()
# Out:
# (6543, 10)
#   Parental_Involvement Access_to_Resources Motivation_Level Internet_Access  \
# 0                  Low                High              Low             Yes
# 1                  Low              Medium              Low             Yes
# 2               Medium              Medium           Medium             Yes
# 3                  Low              Medium           Medium             Yes
# 4               Medium              Medium           Medium             Yes
#
#    Tutoring_Sessions Teacher_Quality Learning_Disabilities  Hours_Studied  \
# 0                  0          Medium                    No             23
# 1                  2          Medium                    No             19
# 2                  2          Medium                    No             24
# 3                  1          Medium                    No             29
# 4                  3            High                    No             19
#
#    Attendance  Exam_Score
# ...

# %%
main_student_df.hist(figsize = (30,15), bins = 30)
# Out:
# array([[<Axes: title={'center': 'Tutoring_Sessions'}>,
#         <Axes: title={'center': 'Hours_Studied'}>],
#        [<Axes: title={'center': 'Attendance'}>,
#         <Axes: title={'center': 'Exam_Score'}>]], dtype=object)

# %% [markdown]
# # 5. Benchmark Model

# %%
benchmark_model_data = main_student_df.copy()

# %%
benchmark_model_data
# Out:
#      Parental_Involvement Access_to_Resources Motivation_Level  \
# 0                     Low                High              Low
# 1                     Low              Medium              Low
# 2                  Medium              Medium           Medium
# 3                     Low              Medium           Medium
# 4                  Medium              Medium           Medium
# ...                   ...                 ...              ...
# 6602                 High              Medium           Medium
# 6603                 High              Medium           Medium
# 6604               Medium                 Low              Low
# 6605                 High                High             High
# 6606               Medium                 Low           Medium
#
#      Internet_Access  Tutoring_Sessions Teacher_Quality Learning_Disabilities  \
# 0                Yes                  0          Medium                    No
# ...

# %%
categorical_features_benchmark = ['Parental_Involvement', 'Access_to_Resources', 'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions', 'Teacher_Quality', 'Learning_Disabilities']
input_features_benchmark = categorical_features_benchmark + ['Hours_Studied', 'Attendance']
target_feature_benchmark = 'Exam_Score'

# %% [markdown]
# ## 5.1. Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X_bench = benchmark_model_data[input_features_benchmark]
y_bench = benchmark_model_data[target_feature_benchmark]

# one-hot encode
X_bench = pd.get_dummies(X_bench)

X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(X_bench, y_bench, test_size=0.33, random_state=42)

# %% [markdown]
# ## 5.2. Fitting a model to a data

# %%
from sklearn.tree import DecisionTreeRegressor 

tree = DecisionTreeRegressor(max_depth=10)
tree.fit(X_train_b, y_train_b)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
model_at_hand = tree

y_pred_b = model_at_hand.predict(X_test_b)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('mean_absolute_error', mean_absolute_error(y_test_b, y_pred_b))
print('mean_squared_error', mean_squared_error(y_test_b, y_pred_b))
print('root_mean_squared_error', sqrt(mean_squared_error(y_test_b, y_pred_b)))
print('r2', r2_score(y_test_b, y_pred_b))
# Out:
# mean_absolute_error 1.5049904171885133
# mean_squared_error 4.867817592871696
# root_mean_squared_error 2.206313122127432
# r2 0.5731992273803328

# %%
data = {'true': y_test_b, 'pred': y_pred_b}
results = pd.DataFrame(data)

results.plot(figsize=(20,10), kind='scatter', x='true', y='pred')
# Out:
# <Axes: xlabel='true', ylabel='pred'>

# %% [markdown]
# # 6. Model Training

# %% [markdown]
# ## 6.1. Random Forest

# %%
data_for_model = benchmark_model_data.copy()

# %%
categorical_features_benchmark = ['Parental_Involvement', 'Access_to_Resources', 'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions', 'Teacher_Quality', 'Learning_Disabilities']
input_features_benchmark = categorical_features_benchmark + ['Hours_Studied', 'Attendance']
target_feature_benchmark = 'Exam_Score'

# %%
from sklearn.model_selection import train_test_split

X = data_for_model[input_features_benchmark]
y = data_for_model[target_feature_benchmark]

# one-hot encode
X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

forest_model = RandomForestRegressor()
forest_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
model_at_hand = forest_model

y_pred = model_at_hand.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('mean_absolute_error', mean_absolute_error(y_test, y_pred))
print('mean_squared_error', mean_squared_error(y_test, y_pred))
print('root_mean_squared_error', sqrt(mean_squared_error(y_test, y_pred)))
print('r2', r2_score(y_test, y_pred))
# Out:
# mean_absolute_error 1.1391710868606701
# mean_squared_error 2.4932211562611544
# root_mean_squared_error 1.5789937163463172
# r2 0.7813992214165516

# %%
data = {'true': y_test, 'pred': y_pred}
results = pd.DataFrame(data)

results.plot(figsize=(20,10), kind='scatter', x='true', y='pred')
# Out:
# <Axes: xlabel='true', ylabel='pred'>

# %% [markdown]
# ## 6.2. Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingRegressor

gradBooster = GradientBoostingRegressor()
gradBooster.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
model_at_hand = gradBooster

y_pred = model_at_hand.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('mean_absolute_error', mean_absolute_error(y_test, y_pred))
print('mean_squared_error', mean_squared_error(y_test, y_pred))
print('root_mean_squared_error', sqrt(mean_squared_error(y_test, y_pred)))
print('r2', r2_score(y_test, y_pred))
# Out:
# mean_absolute_error 0.9952774263019099
# mean_squared_error 1.9602055212632312
# root_mean_squared_error 1.4000733985271026
# r2 0.8281329949187897

# %%
data = {'true': y_test, 'pred': y_pred}
results = pd.DataFrame(data)

results.plot(figsize=(20,10), kind='scatter', x='true', y='pred')
# Out:
# <Axes: xlabel='true', ylabel='pred'>

# %%
(pd.Series(model_at_hand.feature_importances_, index=X_train.columns)
   .nlargest(10)
   .plot(kind='barh'))
# Out:
# <Axes: >

# %% [markdown]
# # 7. Tuning

# %% [markdown]
# ## 7.1. Best Parameter

# %%
learning_rate = [0.001, 0.005, 0.01, 0.002, 0.05, 0.1, 0.2, 0.3]

n_estimators = [int(x) for x in np.linspace(start = 100, stop = 2000, num = 20)]

subsample = [0.8, 0.9, 1.0]

min_samples_split = [2, 5, 10, 20, 40]

min_samples_leaf = [1, 2, 4, 10, 20]

max_features = [None, 'sqrt']

max_depth = [10,20,50,100,150,200,300,500]
max_depth.append(None)

# %%
import pprint as pp

# Create the random grid
grad_grid = {'n_estimators': n_estimators,
             'learning_rate': learning_rate,
             'subsample': subsample,
             'min_samples_split': min_samples_split,
             'min_samples_leaf': min_samples_leaf,
             'max_features': max_features,
             'max_depth': max_depth}
pp.pprint(grad_grid)
# Out:
# {'learning_rate': [0.001, 0.005, 0.01, 0.002, 0.05, 0.1, 0.2, 0.3],
#  'max_depth': [10, 20, 50, 100, 150, 200, 300, 500, None],
#  'max_features': [None, 'sqrt'],
#  'min_samples_leaf': [1, 2, 4, 10, 20],
#  'min_samples_split': [2, 5, 10, 20, 40],
#  'n_estimators': [100,
#                   200,
#                   300,
#                   400,
#                   500,
#                   600,
#                   700,
#                   800,
#                   900,
#                   1000,
#                   1100,
#                   1200,
#                   1300,
#                   1400,
#                   1500,
#                   1600,
#                   1700,
#                   1800,
#                   1900,
#                   2000],
#  'subsample': [0.8, 0.9, 1.0]}

# %%
from sklearn.model_selection import RandomizedSearchCV

gb = GradientBoostingRegressor()

gb_random = RandomizedSearchCV(estimator = gb, param_distributions = grad_grid, n_iter = 50, cv = 3, verbose=2, random_state=42, n_jobs = -1)

# Fit the random search model
gb_random.fit(X_train, y_train)

performances = pd.DataFrame.from_dict(gb_random.cv_results_)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits

# %%
sorted_performances = performances.sort_values(by='rank_test_score')
sorted_performances.head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 41       6.256775      0.141664         0.213301        0.013642
# 29      26.682182      0.689430         0.354946        0.009938
# 18      14.276354      0.736931         0.182441        0.017870
# 21       7.727588      0.073176         0.283804        0.009070
# 47       1.698769      0.043484         0.061009        0.000849
#
#    param_subsample param_n_estimators param_min_samples_split  \
# 41             0.9                900                       2
# 29             0.8               1600                       5
# 18             0.8                800                       2
# 21             1.0               1200                       2
# 47             0.8                300                      20
#
#    param_min_samples_leaf param_max_features param_max_depth  \
# 41                     20               sqrt             100
# 29                     20               None              20
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

import time
t0= time.time()

best = GradientBoostingRegressor(subsample=0.9, n_estimators=800, min_samples_split= 2,
min_samples_leaf=20,
max_features= 'sqrt',
max_depth= 100,
learning_rate=0.01)
best.fit(X_train, y_train)

t1 = time.time() - t0
print("Time elapsed: ", t1, " seconds")


model_at_hand = best

y_pred = model_at_hand.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('mean_absolute_error', mean_absolute_error(y_test, y_pred))
print('mean_squared_error', mean_squared_error(y_test, y_pred))
print('root_mean_squared_error', sqrt(mean_squared_error(y_test, y_pred)))
print('r2', r2_score(y_test, y_pred))
# Out:
# Time elapsed:  3.728523015975952  seconds
# mean_absolute_error 1.0148213617031665
# mean_squared_error 1.982213461416651
# root_mean_squared_error 1.4079110275215017
# r2 0.82620338155879

# %%
data = {'true': y_test, 'pred': y_pred}
results = pd.DataFrame(data)

results.plot(figsize=(20,10), kind='scatter', x='true', y='pred')
# Out:
# <Axes: xlabel='true', ylabel='pred'>

# %%
benchmark_model_data['Exam_Score'].hist(figsize=(10,5), bins=30)
# Out:
# <Axes: >

# %%
student_score_class = benchmark_model_data.copy()
student_score_class['score_class'] = student_score_class['Exam_Score'].apply(lambda x: 'low' if x <= 67 else 'high')
student_score_class['score_class_binary'] = student_score_class['score_class'].apply(lambda x: 0 if x == 'low' else 1)
student_score_class.head()
# Out:
#   Parental_Involvement Access_to_Resources Motivation_Level Internet_Access  \
# 0                  Low                High              Low             Yes
# 1                  Low              Medium              Low             Yes
# 2               Medium              Medium           Medium             Yes
# 3                  Low              Medium           Medium             Yes
# 4               Medium              Medium           Medium             Yes
#
#    Tutoring_Sessions Teacher_Quality Learning_Disabilities  Hours_Studied  \
# 0                  0          Medium                    No             23
# 1                  2          Medium                    No             19
# 2                  2          Medium                    No             24
# 3                  1          Medium                    No             29
# 4                  3            High                    No             19
#
#    Attendance  Exam_Score score_class  score_class_binary
# ...

# %%
student_score_class['score_class'].value_counts()
# Out:
# score_class
# low     3592
# high    2951
# Name: count, dtype: int64

# %%
categorical_features = ['Parental_Involvement', 'Access_to_Resources', 'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions', 'Teacher_Quality', 'Learning_Disabilities']
input_features = categorical_features_benchmark + ['Hours_Studied', 'Attendance']
target_feature = 'score_class_binary'

# %%
from sklearn.model_selection import train_test_split

X_c = student_score_class[input_features]
y_c = student_score_class[target_feature]

# one-hot encode
X_c = pd.get_dummies(X_c)

X_train_c, X_test_c, y_train_c, y_test_c = train_test_split(X_c, y_c, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier()
clf.fit(X_train_c, y_train_c)

y_pred_c = clf.predict(X_test_c)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import confusion_matrix
from math import sqrt

print(confusion_matrix(y_test_c, y_pred_c))

print('accuracy', accuracy_score(y_test_c, y_pred_c))
print('precision', precision_score(y_test_c, y_pred_c))
print('recall', recall_score(y_test_c, y_pred_c))
# Out:
# [[1077  100]
#  [ 125  858]]
# accuracy 0.8958333333333334
# precision 0.8956158663883089
# recall 0.8728382502543235

# %%
(pd.Series(clf.feature_importances_, index=X_train.columns)
   .nlargest(10)
   .plot(kind='barh'))
# Out:
# <Axes: >

# %% [markdown]
# | Algorithm               | MAE   | RMSE  | R2    |
# |-------------------------|-------|-------|-------|
# | Benchmark model         | 1.504 | 2.206 | 0.573 |
# | Random forest           | 1.139 | 1.579 | 0.781 |
# | Gradient boosting       | 0.995 | 1.400 | 0.828 |
# | Tuned Gradient boosting | 1.014 | 1.407 | 0.826 |
